# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhamvermapersonal/da_notes/blob/main/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = 5
height = 4.0
name = "shubham"

# %%
a,b,c = 12,15,22

# %%
print(a)
# Out:
# 12

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Swapping**

# %%
num1 = 12
num2 = 14

print(num1,num2)

num1, num2 = num2, num1

print(num1,num2)
# Out:
# 12 14
# 14 12

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Data Type Conversion**

# %%
num1=12
num2="14"

print(num1+int(num2))
# Out:
# 26

# %%
num =bool(0)
print(type(num))
print(num)
# Out:
# <class 'bool'>
# False
